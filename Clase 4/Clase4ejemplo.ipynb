# %% [markdown]
# # Repaso de la clase anterior

# %%
#Variables

doc = int ( input("\nPor favor, ingresar su documento:\n") )

altura = float ( input("\nPor favor, ingresar tu altura:\n") )

peso = float ( input("\nPor favor, ingresar tu peso:\n") )
# Out:
# Por favor, ingresar su documento:
# 122121
#
# Por favor, ingresar tu altura:
# 1.81
#
# Por favor, ingresar tu peso:
# 91.32

# %%
lista_datos_persona = [doc, altura, peso]

# %%
lista_datos_persona
# Out:
# [122121, 1.81, 91.32]

# %%
lista_datos_persona[1]
# Out:
# 1.81

# %%
sum(lista_datos_persona)
# Out:
# 122214.13

# %%
#Estados lógicos---- 0 - 1  ---- False --- True

peso == altura
# Out:
# False

# %%
(peso > altura )  and not (doc < peso)   #<------------- Trabajar hoy :/
# Out:
# True

# %% [markdown]
# # Control de flujo de decisión

# %% [markdown]
# # if

# %%
if ((not peso < 80)  or (peso == 82)):

  print("Usted esta muy bien :( ")
  print("\n-----------------\n")
  print("Otra clase epica :) ")
# Out:
# Usted esta muy bien :(
#
# -----------------
#
# Otra clase epica :)

# %%
numero = 6

if (  numero%2 == 0 ):
  print("Tu numero  es par :)")

if ( numero%3 == 0):
  print("Tu numero es divisible por 3 :)")

if (numero > 10):
  print("Tu numero es muy grande :( ")
# Out:
# Tu numero  es par :)
# Tu numero es divisible por 3 :)

# %%
#IF DENTRO DE IF O________O

print(f"----> {peso}")

if ( peso < 100):

      print("Usted pesa menos que 100")

      if ( peso <90):

            print("Estas muy flaquito")
# Out:
# ----> 91.32
# Usted pesa menos que 100

# %% [markdown]
# # Else

# %%
print(f"DOC: ----> {doc}")

if ( doc % 2 == 0 ):

    print("EL DOCUMENTO ES MUY LINDO Y ES PAR!!!!!!")  #True

else:   #SINO -----> False

    print("Tu documento es muy feo :(")
# Out:
# DOC: ----> 122121
# Tu documento es muy feo :(

# %%
#Pidan por input una edad.... y que muestra que sos mayor de edad o que sos menor de edad,
#solamente si la edad es par... si la edad es impar no hacer nada :(

##edad = 21    

#if ( edad > 18 and edad % 2 == 0) :

  #print("sos mayor de edad")

#else:

  #print("sos menor")
# Out:
# sos menor

# %% [markdown]
# # Elif

# %%
print(f"DOC: ----> {doc}")

if ( doc % 2 == 0 ):

    print("EL DOCUMENTO ES MUY LINDO Y ES PAR!!!!!!")  #True

elif  (peso < 80):   #SINO, si (blabla) -----> False

    print("Excelente ingresaste al elif")
# Out:
# DOC: ----> 122121

# %%
edad =  23
if edad >= 36:

		print("Es un adulto.")
  
elif edad == 24:

		print("La edad es 24")
else:
		print("No sabemos la edad")
# Out:
# No sabemos la edad

# %%
comando =  "SALUDO"

if (comando == "ENTRAR"):

		print("Bienvenido al sistema.")
  
elif (comando == "SALUDO"):
  
		print("Hola! ¿Cómo estás?")
  
elif (comando == "SALIR"):
		print("Saliendo del sistema.")
  
else:
		print("No se reconoce el comando.")
# Out:
# Hola! ¿Cómo estás?

# %%
participantes = 144

if ( participantes > 150):  #.......

  pass

else: 

  print("Son poquitos!!!!")
# Out:
# Son poquitos!!!!

# %%
Edad = int (   input("Ingresar edad") )

if (Edad < 18):
  print("Menor de edad")

else:
  print("Mayor de edad")
# Out:
# Edad = 1633
# Mayor de edad

# %% [markdown]
# # Ayuda desafio Marvel

# %%
nombre = "Nicolas"   #input
fan = "Capcom"    #input

#Grupo A ------

#Fanatico de marvel

# fan == "Marvel"
# nombre < "M"

if (fan == "Marvel" and nombre < "M") or (fan == "Capcom" and nombre > "N"):

  print("SOS DEL GRUPO A")

else: 

  print("Sos del epico grupo B!!!!!!!!!")
# Out:
# SOS DEL GRUPO A
