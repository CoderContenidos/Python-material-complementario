# %% [markdown]
# #Ejercicio 0
# Crea una función esMultiplo que reciba los dos números, y devuelve si el primero es múltiplo del segundo.
#
# #Ejercicio 1
# Crea un programa que pida dos número enteros al usuario y diga si alguno de ellos es múltiplo del otro.
#
#
# #Ejercicio 2
# Crear una función que calcule la temperatura media de un día a partir de la temperatura máxima y mínima.
#
# #Ejercicio 3
# Crear un programa principal, que utilizando la función anterior, vaya pidiendo la temperatura máxima y mínima de cada día y vaya mostrando la media. El programa pedirá el número de días que se van a introducir.
#
#
# #Ejercicio 4
# Crea una función “calcularMaxMin” que recibe una lista con valores numéricos y devuelve el valor máximo y el mínimo.
#
#
# #Ejercicio 6
# Diseñar una función que calcule el área y el perímetro de una circunferencia.
#
# #Ejercicio 7
# Crear una subrutina llamada “Login”, que recibe un nombre de usuario y una contraseña y te devuelve Verdadero si el nombre de usuario es “usuario1” y la contraseña es “asdasd”.
#
# #Ejercicio 8
# Crear un programa principal donde se pida un nombre de usuario y una contraseña y se intente hacer login, solamente tenemos tres oportunidades para intentarlo.
#
# #Ejercicio 9
# Crear una función  que permita calcular el factorial de un número.

# %%
#Ejercicio 0
#Crea una función esMultiplo que reciba los dos números,
# y devuelve si el primero es múltiplo del segundo.

def esMultiplo(n1, n2):

    #Mejorar estas cosas :) 
    if(type(n1)!=int or type(n2)!=int ):

      print("No me hago cargo de lo que de esto :(")


    #qué tengo que hacer.....
    resultado = False

    if ( n1 % n2 == 0 ):

      resultado = True

    #qué tengo que retornar... ????
    return resultado
    #print(f"El resultado es: {resultado}")

# %%
esMultiplo(100, 10)
# Out:
# El resultado es: True

# %%
#Ejercicio 1
#Crea una función  que pida dos número enteros 
#al usuario y diga si alguno de ellos es múltiplo del otro.

def esAlgunoMultiplo():

    num1 = int (input("Ingresar un entero\n"))

    num2 = int (input("Ingresar un entero\n"))

    resultado = False

    resultado = esMultiplo(num1, num2) or esMultiplo(num2, num1)

    return resultado

# %%
esAlgunoMultiplo()
# Out:
# Ingresar un entero
# 100
# Ingresar un entero
# 0
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# <ipython-input-21-6c4cc572cadb> in <module>()
# ----> 1 esAlgunoMultiplo()
#
# <ipython-input-11-899433dca789> in esAlgunoMultiplo()
#      11     resultado = False
#      12
# ---> 13     resultado = esMultiplo(num1, num2) or esMultiplo(num2, num1)
#      14
#      15     return resultado
#
# <ipython-input-18-d127ad5b0d62> in esMultiplo(n1, n2)
#      13     resultado = False
#      14
# ---> 15     if ( n1 % n2 == 0 ):
#      16
#      17       resultado = True
#
# ZeroDivisionError: integer division or modulo by zero

# %%
#Ejercicio 0
#Crea una función esMultiplo que reciba los dos números,
# y devuelve si el primero es múltiplo del segundo.

def esMultiploPRO(n1, n2):

  
    return ( n1 % n2 == 0 )

# %%
esMultiploPRO(120,12)
# Out:
# True

# %%
esMultiplo(12.2, 1.22) #<----FALSE?????????:(
# Out:
# No me hago cargo de lo que de esto :(
# False

# %%
print("Nico"
# Out:
#   File "<ipython-input-27-05e0ba8d7812>", line 1
#     print("Nico"
#                 ^
# SyntaxError: unexpected EOF while parsing

# %%
try:

    n = float(input("Ingresar n:\n") ) #input dan una cadena

    m = 4

    print(f"---> {n}/{m} = {n/m}")

except:

  print("Algo salio!!!! :( ")
# Out:
# Ingresar n:
# 9
# ---> 9.0/4 = 2.25

# %%
while(True):
    #TRY es obligatorio y except
    try:
      nombre = input("Ingresar su nombre\n")

      n = float(input("Ingresar un n\n"))

    except:
      print("Estas loco no puedo castear esto!!!!")

    #BLOQUE OPCIONAL
    else:  #else se ejecuta cuando no entraste al except

      print("Todo salio bien, gracias")
      break

    #BLOQUE OPCIONAL
    finally:

      print(f"Gracias por estar presente {nombre}")
# Out:
# Ingresar su nombre
# nico
# Ingresar un n
# 3
# Todo salio bien, gracias
# Gracias por estar presente nico

# %%
try:
    n = input("Introduce un número: ")  # no transformamos a número
    
    5/n

except Exception as e1:  # guardamos la excepción como una variable e

    print(f"Ha ocurrido un error => {e1}")
    print(f"Ha ocurrido un error => {type(e1).__name__}")
# Out:
# Introduce un número: 7
# Ha ocurrido un error => unsupported operand type(s) for /: 'int' and 'str'
# Ha ocurrido un error => TypeError

# %%
try:
    		n = float(input("Introduce un número divisor: "))
    		5/n
        
except TypeError:
    		print("No se puede dividir el número entre una cadena")
except ValueError:
    		print("Debes introducir una cadena que sea un número")
except ZeroDivisionError:
    		print("No se puede dividir por cero, prueba otro número")
except Exception as e:
    		print("Ha ocurrido un error no previsto", type(e).__name__ )
# Out:
# Introduce un número divisor: "0/n"
# Debes introducir una cadena que sea un número

# %%
def dividir(a,b):

  try: 
    print("----Arrancandooo!!!!!-----")
    a/b

  except:

    print("No se pudo dividir")

  else:

    print("Que bueno que se pudo dividir!!!")

  finally:

    print("Gracias por usar mi función!!!")

# %%
dividir(5,9)
# Out:
# ----Arrancandooo!!!!!-----
# Que bueno que se pudo dividir!!!
# Gracias por usar mi función!!!
