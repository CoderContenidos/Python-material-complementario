# %% [markdown]
# # Ayuda Desafio clase 8

# %%
#---------- nota1 ---- nota2 ------- 0-10 -------- prome>7 aprobabas---4 y 7 ---final

import sys

#Validar si hay dos notas o no...


if len(sys.argv) == 3: #Validamos que son dos notas :) 

  #Guardar en otra variable
  nota1 = sys.argv[1]
  nota2 = sys.argv[2]

  nota1_bien = False
  nota2_bien = False

  #Validar que estan entre 0 y 10

  if ( nota1>=0 and nota1<=10 ):  #Vamos bien :) 

    nota1_bien = True

  else: 

    print("Error con la nota 1")



  if ( nota2>=0 and nota2<=10 ):  #Vamos bien :) 

    nota2_bien = True

  else: 

    print("Error con la nota 2")




  #Dar las respuestas 
  if ( nota1_bien and nota2_bien):

    if ( nota1 >= 7 and nota2 >= 7):

      print("Felicidades promoción")

    #Ver los otros casos
	

else:


	print("Paremetros incorrectos")

# %% [markdown]
# # Repaso

# %%
# Mostrar los numeros impares entre 5 y el 40

for x in range(5,40,2):

  print(f"Este número cumple: {x}")
# Out:
# Este número cumple: 5
# Este número cumple: 7
# Este número cumple: 9
# Este número cumple: 11
# Este número cumple: 13
# Este número cumple: 15
# Este número cumple: 17
# Este número cumple: 19
# Este número cumple: 21
# Este número cumple: 23
# Este número cumple: 25
# Este número cumple: 27
# Este número cumple: 29
# Este número cumple: 31
# Este número cumple: 33
# Este número cumple: 35
# Este número cumple: 37
# Este número cumple: 39

# %%
for x in range(5, 40):

  if ( x % 2 == 1):

    print(f"Este número no es divisible por 2: {x}")
# Out:
# Este número no es divisible por 2: 5
# Este número no es divisible por 2: 7
# Este número no es divisible por 2: 9
# Este número no es divisible por 2: 11
# Este número no es divisible por 2: 13
# Este número no es divisible por 2: 15
# Este número no es divisible por 2: 17
# Este número no es divisible por 2: 19
# Este número no es divisible por 2: 21
# Este número no es divisible por 2: 23
# Este número no es divisible por 2: 25
# Este número no es divisible por 2: 27
# Este número no es divisible por 2: 29
# Este número no es divisible por 2: 31
# Este número no es divisible por 2: 33
# Este número no es divisible por 2: 35
# Este número no es divisible por 2: 37
# Este número no es divisible por 2: 39

# %%
#Mostrar los numeros entre -11 y 108 que no sean divisibles por 3
for x in range(-11, 108):

  if ( not (x % 3 == 0) ):
  #if ( (x % 3 != 0) ):
  #if ( x % 3 == 1 or  x % 3 == 2 ):

    print(f"Este numero no es divisible por 3: {x}")
# Out:
# Este numero no es divisible por 3: -11
# Este numero no es divisible por 3: -10
# Este numero no es divisible por 3: -8
# Este numero no es divisible por 3: -7
# Este numero no es divisible por 3: -5
# Este numero no es divisible por 3: -4
# Este numero no es divisible por 3: -2
# Este numero no es divisible por 3: -1
# Este numero no es divisible por 3: 1
# Este numero no es divisible por 3: 2
# Este numero no es divisible por 3: 4
# Este numero no es divisible por 3: 5
# Este numero no es divisible por 3: 7
# Este numero no es divisible por 3: 8
# Este numero no es divisible por 3: 10
# Este numero no es divisible por 3: 11
# Este numero no es divisible por 3: 13
# Este numero no es divisible por 3: 14
# Este numero no es divisible por 3: 16
# Este numero no es divisible por 3: 17
# Este numero no es divisible por 3: 19
# Este numero no es divisible por 3: 20
# Este numero no es divisible por 3: 22
# Este numero no es divisible por 3: 23
# Este numero no es divisible por 3: 25
# Este numero no es divisible por 3: 26
# Este numero no es divisible por 3: 28
# Este numero no es divisible por 3: 29
# Este numero no es divisible por 3: 31
# Este numero no es divisible por 3: 32
# Este numero no es divisible por 3: 34
# Este numero no es divisible por 3: 35
# Este numero no es divisible por 3: 37
# Este numero no es divisible por 3: 38
# Este numero no es divisible por 3: 40
# Este numero no es divisible por 3: 41
# Este numero no es divisible por 3: 43
# Este numero no es divisible por 3: 44
# Este numero no es divisible por 3: 46
# Este numero no es divisible por 3: 47
# Este numero no es divisible por 3: 49
# Este numero no es divisible por 3: 50
# Este numero no es divisible por 3: 52
# Este numero no es divisible por 3: 53
# Este numero no es divisible por 3: 55
# Este numero no es divisible por 3: 56
# Este numero no es divisible por 3: 58
# Este numero no es divisible por 3: 59
# Este numero no es divisible por 3: 61
# Este numero no es divisible por 3: 62
# Este numero no es divisible por 3: 64
# Este numero no es divisible por 3: 65
# Este numero no es divisible por 3: 67
# Este numero no es divisible por 3: 68
# Este numero no es divisible por 3: 70
# Este numero no es divisible por 3: 71
# Este numero no es divisible por 3: 73
# Este numero no es divisible por 3: 74
# Este numero no es divisible por 3: 76
# Este numero no es divisible por 3: 77
# Este numero no es divisible por 3: 79
# Este numero no es divisible por 3: 80
# Este numero no es divisible por 3: 82
# Este numero no es divisible por 3: 83
# Este numero no es divisible por 3: 85
# Este numero no es divisible por 3: 86
# Este numero no es divisible por 3: 88
# Este numero no es divisible por 3: 89
# Este numero no es divisible por 3: 91
# Este numero no es divisible por 3: 92
# Este numero no es divisible por 3: 94
# Este numero no es divisible por 3: 95
# Este numero no es divisible por 3: 97
# Este numero no es divisible por 3: 98
# Este numero no es divisible por 3: 100
# Este numero no es divisible por 3: 101
# Este numero no es divisible por 3: 103
# Este numero no es divisible por 3: 104
# Este numero no es divisible por 3: 106
# Este numero no es divisible por 3: 107

# %%
#Mostrar los numeros entre 1 y 33 que no sean divisibles por 7


for x in range(1, 33):

  if ( not (x % 7 == 0) ):
  #if ( (x % 3 != 0) ):
  #if ( x % 3 == 1 or  x % 3 == 2 ):

    print(f"Este numero no es divisible por 7: {x}")
# Out:
# Este numero no es divisible por 7: 1
# Este numero no es divisible por 7: 2
# Este numero no es divisible por 7: 3
# Este numero no es divisible por 7: 4
# Este numero no es divisible por 7: 5
# Este numero no es divisible por 7: 6
# Este numero no es divisible por 7: 8
# Este numero no es divisible por 7: 9
# Este numero no es divisible por 7: 10
# Este numero no es divisible por 7: 11
# Este numero no es divisible por 7: 12
# Este numero no es divisible por 7: 13
# Este numero no es divisible por 7: 15
# Este numero no es divisible por 7: 16
# Este numero no es divisible por 7: 17
# Este numero no es divisible por 7: 18
# Este numero no es divisible por 7: 19
# Este numero no es divisible por 7: 20
# Este numero no es divisible por 7: 22
# Este numero no es divisible por 7: 23
# Este numero no es divisible por 7: 24
# Este numero no es divisible por 7: 25
# Este numero no es divisible por 7: 26
# Este numero no es divisible por 7: 27
# Este numero no es divisible por 7: 29
# Este numero no es divisible por 7: 30
# Este numero no es divisible por 7: 31
# Este numero no es divisible por 7: 32

# %%
print(f"HOLA SOY EL : ---> {6}")

#len(lista)

#input()

#sum()

#NOMBRE(    parametros   )
# Out:
# HOLA SOY EL : ---> 6

# %%
#Mi primer función

def funcion_saludar():

  print("Hola Coder")
  print("----------")
  print("Soy muy buenoooo")

# %%
funcion_saludar()
# Out:
# Hola Coder
# ----------
# Soy muy buenoooo

# %%
def funcion_saludar_nombre(nombre):  #nombre es mi parametro de entrada

  print("Hola Coder")
  print("----------")
  print(f"El mejor es: {nombre}")

# %%
funcion_saludar_nombre("Nico")  #Le envio un Nico
# Out:
# Hola Coder
# ----------
# El mejor es: Nico

# %%
funcion_saludar_nombre("Nadia!!!")
# Out:
# Hola Coder
# ----------
# El mejor es: Nadia!!!

# %%
pepe = "Agustin"

# %%
funcion_saludar_nombre(pepe)
# Out:
# Hola Coder
# ----------
# El mejor es: Agustin

# %%
nombre  #No funciona porque vive solo en la funcion, variable Local :)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-18-537e465e3aa0> in <module>()
# ----> 1 nombre
#
# NameError: name 'nombre' is not defined

# %%
variable_test = 10  #Vive en todo mi colabs --- Variable global

# %%
def test():
  variable_test = 15
  print(f"{variable_test}")

# %%
test()
# Out:
# 15

# %%
variable_test
# Out:
# 10

# %%
#Las funciones anteriores .... "Procedimientos"

# %%
def saludo_nombre(nombre):

  saludo = f"Hasta pronto, {nombre} gracias por venir!!!"

  return saludo

# %%
saludo_nombre("Pepe")
# Out:
# 'Hasta pronto, Pepe gracias por venir!!!'

# %%
#Procedimiento
def suma1 (a,b ):

  resultado = a + b
  print(f"El resultado de la suma es: {resultado}")

# %%
suma1(11, 9)
# Out:
# El resultado de la suma es: 20

# %%
#Función 
def suma2 (a,b ):

  resultado = a + b
  
  return resultado

# %%
variable = suma2(11,9)  #variable <------ 20

# %%
def restarNumeros(numero1, numero2):

  resultado = numero1 - numero2

  return resultado

# %%
#Forma A
var1 = restarNumeros(5,1)

# %%
var1
# Out:
# 4

# %%
#Forma B
print(f"RESULTADO DE LA RESTA {restarNumeros(519,111)}")
# Out:
# RESULTADO DE LA RESTA 408

# %%
var1 = restarNumeros(1,7)

# %%
var1
# Out:
# -6

# %%
#Mostrar los numeros entre -11 y 108 que no sean divisibles por 3

def numeros_entre_no_divisibles(desde, hasta, noDivisible ):

        for x in range(desde, hasta):

          if ( not (x % noDivisible == 0) ):


            print(f"Este numero no es divisible por {noDivisible}: {x}")

# %%
numeros_entre_no_divisibles(-1001, 3, 2)  #10 11 13 14 15 17 18 ...

# %%
def esPar(numero):

  #Recordar type()

  if ( type(numero) == int):

        if ( numero % 2 == 0):

          print("PAR")

        else: 
          
          print("IMPAR")

  else: 

        print("ERROR, mandame un entero")

# %%
esPar("Nico")
# Out:
# ERROR, mandame un entero
